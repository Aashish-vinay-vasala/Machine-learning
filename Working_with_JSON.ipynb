# %%
import numpy as np
import pandas as pd
import requests

# %%
url = "https://raw.githubusercontent.com/Data-for-Palestine/Palestinian-Movies-JSON-Dataset/main/palestinian_movies.json"

# %%
req = requests.get(url)

# %%
req.json()
# Out:
# {'movies': [{'titleText': {'text': 'Curfew'},
#    'id': 'tt0109996',
#    'primaryImage': {'id': 'rm777481472',
#     'width': 315,
#     'height': 420,
#     'url': 'https://m.media-amazon.com/images/M/MV5BZWJhODQ3NWQtMDk1YS00Y2FlLWE0ZDMtNTlhODUxMzI0MWI3XkEyXkFqcGdeQXVyNzQwMzAwNTI@._V1_.jpg',
#     'caption': {'plainText': 'Curfew (1994)'}},
#    'releaseDate': {'day': 5,
#     'month': 12,
#     'year': 1994,
#     'country': {'id': 'US', 'text': 'United States'}},
#    'plot': {'plotText': {'plainText': '24 hours of family drama during a curfew announced by the Israeli army in a Palestinian refugee camp on the Gaza Strip in 1993.'},
#     'language': {'id': 'en-US'}}},
#   {'titleText': {'text': 'Hikayatul jawahiri thalath'},
#    'id': 'tt0111354',
#    'primaryImage': {'id': 'rm4037123328',
#     'width': 284,
#     'height': 475,
#     'url': 'https://m.media-amazon.com/images/M/MV5BMTk5MTk2Njk5NF5BMl5BanBnXkFtZTcwODk4OTUyMQ@@._V1_.jpg',
# ...

# %%
data = pd.DataFrame(req.json())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   movies  40 non-null     object
# dtypes: object(1)
# memory usage: 448.0+ bytes

# %%
data.head()
# Out:
#                                               movies
# 0  {'titleText': {'text': 'Curfew'}, 'id': 'tt010...
# 1  {'titleText': {'text': 'Hikayatul jawahiri tha...
# 2  {'titleText': {'text': 'Giraffada'}, 'id': 'tt...
# 3  {'titleText': {'text': 'Gaza mon amour'}, 'id'...
# 4  {'titleText': {'text': 'Farha'}, 'id': 'tt1155...

# %%
data['movies']
# Out:
# 0     {'titleText': {'text': 'Curfew'}, 'id': 'tt010...
# 1     {'titleText': {'text': 'Hikayatul jawahiri tha...
# 2     {'titleText': {'text': 'Giraffada'}, 'id': 'tt...
# 3     {'titleText': {'text': 'Gaza mon amour'}, 'id'...
# 4     {'titleText': {'text': 'Farha'}, 'id': 'tt1155...
# 5     {'titleText': {'text': 'Eyes of a Thief'}, 'id...
# 6     {'titleText': {'text': 'Habibi Rasak Kharban'}...
# 7     {'titleText': {'text': 'Falastine Stereo'}, 'i...
# 8     {'titleText': {'text': 'Chronicle of a Disappe...
# 9     {'titleText': {'text': 'Laila's Birthday'}, 'i...
# 10    {'titleText': {'text': 'Lemon Tree'}, 'id': 't...
# 11    {'titleText': {'text': 'Degrade'}, 'id': 'tt44...
# 12    {'titleText': {'text': 'Bethlehem'}, 'id': 'tt...
# 13    {'titleText': {'text': 'Bonboné'}, 'id': 'tt70...
# 14    {'titleText': {'text': 'Between Heaven and Ear...
# 15    {'titleText': {'text': 'In Between'}, 'id': 't...
# 16    {'titleText': {'text': 'Bab el shams'}, 'id': ...
# ...

# %%
data1 = pd.DataFrame(req.json()['movies'])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   titleText     40 non-null     object
#  1   id            40 non-null     object
#  2   primaryImage  40 non-null     object
#  3   releaseDate   40 non-null     object
#  4   plot          40 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %%
data1.head()
# Out:
#                                 titleText          id  \
# 0                      {'text': 'Curfew'}   tt0109996
# 1  {'text': 'Hikayatul jawahiri thalath'}   tt0111354
# 2                   {'text': 'Giraffada'}   tt3132086
# 3              {'text': 'Gaza mon amour'}  tt11692148
# 4                       {'text': 'Farha'}  tt11555492
#
#                                         primaryImage  \
# 0  {'id': 'rm777481472', 'width': 315, 'height': ...
# 1  {'id': 'rm4037123328', 'width': 284, 'height':...
# 2  {'id': 'rm2021999616', 'width': 950, 'height':...
# 3  {'id': 'rm2123225857', 'width': 1080, 'height'...
# 4  {'id': 'rm2816411393', 'width': 4000, 'height'...
#
#                                          releaseDate  \
# 0  {'day': 5, 'month': 12, 'year': 1994, 'country...
# 1  {'day': 6, 'month': 12, 'year': 1995, 'country...
# 2  {'day': 23, 'month': 4, 'year': 2014, 'country...
# 3  {'day': 5, 'month': 11, 'year': 2021, 'country...
# ...

# %%
print("Column names:", data.columns)
print()
# Out:
# Column names: Index(['movies'], dtype='object')

# %%
for column_name in data.columns:
    column_data = data[column_name]
    print(f"{column_name}:")
    print(column_data)
    print()
# Out:
# movies:
# 0     {'titleText': {'text': 'Curfew'}, 'id': 'tt010...
# 1     {'titleText': {'text': 'Hikayatul jawahiri tha...
# 2     {'titleText': {'text': 'Giraffada'}, 'id': 'tt...
# 3     {'titleText': {'text': 'Gaza mon amour'}, 'id'...
# 4     {'titleText': {'text': 'Farha'}, 'id': 'tt1155...
# 5     {'titleText': {'text': 'Eyes of a Thief'}, 'id...
# 6     {'titleText': {'text': 'Habibi Rasak Kharban'}...
# 7     {'titleText': {'text': 'Falastine Stereo'}, 'i...
# 8     {'titleText': {'text': 'Chronicle of a Disappe...
# 9     {'titleText': {'text': 'Laila's Birthday'}, 'i...
# 10    {'titleText': {'text': 'Lemon Tree'}, 'id': 't...
# 11    {'titleText': {'text': 'Degrade'}, 'id': 'tt44...
# 12    {'titleText': {'text': 'Bethlehem'}, 'id': 'tt...
# 13    {'titleText': {'text': 'Bonboné'}, 'id': 'tt70...
# 14    {'titleText': {'text': 'Between Heaven and Ear...
# 15    {'titleText': {'text': 'In Between'}, 'id': 't...
# 16    {'titleText': {'text': 'Bab el shams'}, 'id': ...
# ...

# %%
import numpy as np
import pandas as pd
import requests

# %%
url = "https://raw.githubusercontent.com/Data-for-Palestine/Palestinian-Movies-JSON-Dataset/main/palestinian_movies.json"

# %%
new_req = requests.get(url)

# %%
new_data = pd.DataFrame(new_req.json()['movies'])

# %%
new_data
# Out:
#                                             titleText          id  \
# 0                                  {'text': 'Curfew'}   tt0109996
# 1              {'text': 'Hikayatul jawahiri thalath'}   tt0111354
# 2                               {'text': 'Giraffada'}   tt3132086
# 3                          {'text': 'Gaza mon amour'}  tt11692148
# 4                                   {'text': 'Farha'}  tt11555492
# 5                         {'text': 'Eyes of a Thief'}   tt2993406
# 6                    {'text': 'Habibi Rasak Kharban'}   tt1670646
# 7                        {'text': 'Falastine Stereo'}   tt3121066
# 8            {'text': 'Chronicle of a Disappearance'}   tt0115895
# 9                        {'text': 'Laila's Birthday'}   tt1281951
# 10                             {'text': 'Lemon Tree'}   tt1172963
# 11                                {'text': 'Degrade'}   tt4429074
# 12                              {'text': 'Bethlehem'}   tt2915160
# ...

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     141.956
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     167.366
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     119.775
# 3  The true story of how businessman Oskar Schind...   1993-12-15      94.075
# 4  The defense and the prosecution have rested an...   1957-04-10      80.012
#
#    vote_average  vote_count
# 0         8.700       26385
# 1         8.693       20011
# 2         8.577       12081
# 3         8.567       15489
# 4         8.545        8334

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import requests

# Initialize an empty list to store DataFrames
dfs = []

# Loop through pages
for i in range(1, 429):
    # Make API request
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))

    # Extract relevant data from response and create temporary DataFrame
    temp_df = pd.DataFrame(response.json()['results'], columns=['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count'])

    # Append to list
    dfs.append(temp_df)

# Concatenate all DataFrames in the list
df = pd.concat(dfs, ignore_index=True)

# Print the first few rows of the DataFrame to verify
print(df.head())
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     141.956
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     167.366
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     119.775
# 3  The true story of how businessman Oskar Schind...   1993-12-15      94.075
# 4  The defense and the prosecution have rested an...   1957-04-10      80.012
#
#    vote_average  vote_count
# 0         8.700       26385
# 1         8.693       20011
# 2         8.577       12081
# 3         8.567       15489
# 4         8.545        8334

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     141.956
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     167.366
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     119.775
# 3  The true story of how businessman Oskar Schind...   1993-12-15      94.075
# 4  The defense and the prosecution have rested an...   1957-04-10      80.012
#
#    vote_average  vote_count
# 0         8.700       26385
# 1         8.693       20011
# 2         8.577       12081
# 3         8.567       15489
# 4         8.545        8334
